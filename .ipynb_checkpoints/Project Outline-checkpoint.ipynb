# %% [markdown]
# # Chirped Contra-DC Project Outline
#
# This explains the intent and outline of the chirped contra-DC (CCDC) project. The goals of this project divide in a short-term and a longer-term goals:
#
# - **Short-term goal:** Demonstrate that it is possible to design unlimited-bandwidth contra-DCs using chirp.
#
# - **Long-term goal:** Demonstrate that such contra-DC are UV-litho friendly, can be widely wavelength- and bandwidth-tuned without bandwidth residue.
#
# Hence, the first part would be about fabricating many devices and showing that arbitrary bandwidth values can be attained. If that works, non-uniform heating will be introduced in order to tune the devices.

# %% [markdown]
# ## Arbitrary Bandwidth Demonstration
#
# Here we wish to demonstrate optical filters with the following bandwidths:
#
# $$ BW \in \{10, 15, 20, 25, 30, 35, 40 \} ~nm. $$
#
# In order to do so, we base ourselves on an already-fabricated and measured standard design, which exhibited an 8.9-nm BW. We create a list called MVP containing the best designs.

# %%
# %matplotlib notebook
from Modules import *
from ChirpedContraDC_v2 import *

standard = ChirpedContraDC(period = 318e-9)
standard.simulate(bar=False)

MVP = [standard]
standard.displayResults()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
def chirpProfileV2(p, N_seg, frac):
    p1 = p[0]*np.ones(int(N_seg*frac))
    p2 = np.linspace(p[0], p[1], int(N_seg*(1-2*frac)))
    p2 = np.round(p2/2,9)*2
    p3 = p[1]*np.ones(int(N_seg*frac))

    p1=np.append(p1,p2)
    p1=np.append(p1,p3)
    p1=np.append(p1,p[1])



d_10 = ChirpedContraDC(stages=2, a=1, N=1000, resolution=100, wvl_range=[1500e-9,1600e-9])
d_10.simulate(False)

d_10.displayResults()
# Out:
# Progress: |--------------------------------------------------| 0.0% Complete
#
#
#
#
#
#
#
#
#
#
# Propagating along grating...
# Progress: |--------------------------------------------------| 1.0% Complete
#
#
#
#
#
#
#
#
#
#
# Propagating along grating...
# Progress: |█-------------------------------------------------| 2.0% Complete
#
#
#
#
#
#
#
#
#
#
# Propagating along grating...
# Progress: |█-------------------------------------------------| 3.0% Complete
#
#
#
#
#
#
#
#
#
#
# Propagating along grating...
# Progress: |██------------------------------------------------| 4.0% Complete
#
#
#
#
#
#
#
#
#
#
# Propagating along grating...
# Progress: |██------------------------------------------------| 5.0% Complete
#
#
#
#
#
#
#
#
#
#
# Propagating along grating...
# Progress: |███-----------------------------------------------| 6.0% Complete
#
#
#
#
#
#
#
#
#
#
# Propagating along grating...
# Progress: |███-----------------------------------------------| 7.0% Complete
#
#
#
#
#
# ...
